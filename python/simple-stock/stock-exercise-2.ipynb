# %%
def crawl_world_index():
    url = "https://finance.yahoo.com/world-indices/"
    response = requests.get(url,headers={'User-agent': 'Mozilla/5.0'})

    import io
    f = io.StringIO(response.text)
    dfs = pd.read_html(f)
    return dfs[0]

# %%
import requests
import pandas as pd
import json
import numpy as np
import datetime

def crawl_price(stock_id):

    # from exercise-1 
    return df

# %%
world_index = crawl_world_index()

world_index_history = {}

# %% [markdown]
# # 作業：
# 1. 寫一個for 迴圈，查詢 `world_index` 裡列出的所有世界指數的歷史價位
# 2. 將結果存至變數名為`world_index_history` 的dictionary 資料結構

# %%
# 作業區塊
# for ....

# %% [markdown]
# # 作業：
# 3. 透過畫圖顯示下列歷史價位走勢圖

# %%
for name, history in world_index_history.items():
    history.close.plot()
